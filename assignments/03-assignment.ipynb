# %% [markdown]
# # DATASCI 350 - Data Science Computing
#
# ## Assignment 03 - Git and GitHub
#
# ### Instructions
#
# This assignment evaluates your understanding of the Git commands from lectures 05 to 07 and the GitHub workflow from lecture 06.
#
# You will build a small public repository from scratch: a personal reading list. Work through the tasks in order. Use the exact commit messages and branch names given in each task: the grader checks your commit history against them.
#
# The grader reads your commit history on GitHub. Create and edit files from the command line, not through the GitHub website. Files uploaded through the website lose points.
#
# You must complete this assignment individually. You may use notes, books, and AI tools, but you must submit original work. I strongly recommend that you do not use AI tools to generate your solutions, as this will not help you learn the material. Acknowledge all resources used, including input from classmates and AI, in a short note at the end of your submission. If you are unsure about permissible resources or proper acknowledgement, please ask the instructor.
#
# ### Submission
#
# Please submit two things to Canvas:
#
# 1. The URL of your public GitHub repository.
# 2. This notebook (or a PDF) with the command(s) you used for each task, your written answers, and a screenshot where the task asks for one.

# %% [markdown]
# ### Task 01
#
# Create a directory named `reading-list` and move into it. Initialise it as a Git repository and run `git status`. In one sentence: what does "untracked" mean in the output?

# %% [markdown]
# *Commands, answer, and screenshot (where asked) here.*

# %% [markdown]
# ### Task 02
#
# Create `README.md` containing the line `# My reading list`, using `echo` and a redirect. Stage that specific file (not with `git add .`) and commit with the message "Add README".

# %% [markdown]
# *Commands, answer, and screenshot (where asked) here.*

# %% [markdown]
# ### Task 03
#
# Run `git log` and then `git log --oneline`. In two sentences: what information does each line of the `--oneline` output show, and how does it identify a commit?

# %% [markdown]
# *Commands, answer, and screenshot (where asked) here.*

# %% [markdown]
# ### Task 04
#
# Create a `.gitignore` file with two lines: `drafts/` and `*.tmp`. Then create the directory `drafts` and an empty file `drafts/ideas.tmp` inside it. Run `git status`, then `git status --ignored`, and take a screenshot of the second output showing the ignored paths. Commit `.gitignore` with the message "Add gitignore".

# %% [markdown]
# *Commands, answer, and screenshot (where asked) here.*

# %% [markdown]
# ### Task 05
#
# Create and switch to a branch named `recommendations` in a single command. On it, create `books/recommendations.md` with two book entries (any two books you like, one per line). Commit with the message "Add recommendations".

# %% [markdown]
# *Commands, answer, and screenshot (where asked) here.*

# %% [markdown]
# ### Task 06
#
# Switch back to `main` and merge `recommendations`. Delete the merged branch. Show the branch list before and after the deletion, with a screenshot of each.

# %% [markdown]
# *Commands, answer, and screenshot (where asked) here.*

# %% [markdown]
# ### Task 07
#
# Create a new public repository named `reading-list` on GitHub (do not initialise it with a README). Connect your local repository to it with `git remote add origin`, then push with `git push -u origin main`. In one sentence: what does the `-u` flag do? Paste your repository URL here.

# %% [markdown]
# *Commands, answer, and screenshot (where asked) here.*

# %% [markdown]
# ### Task 08
#
# Create and switch to a branch named `more-books`. Add two more titles to `books/recommendations.md`. Commit with the message "Add two novels" and push the branch to GitHub. On GitHub, open a pull request titled "Add two novels" and merge it with a merge commit (the default option, not squash or rebase). Back in your terminal, switch to `main` and run `git pull`. Take a screenshot of the merged pull request page.

# %% [markdown]
# *Commands, answer, and screenshot (where asked) here.*

# %% [markdown]
# ### Task 09
#
# Append one more title to `books/recommendations.md` and commit with the message "Add boks" (with this exact typo). Then fix the message with a single command so it reads "Add books". In one sentence: why should you not do this to a commit you have already pushed?

# %% [markdown]
# *Commands, answer, and screenshot (where asked) here.*

# %% [markdown]
# ### Task 10
#
# Modify `README.md` (change any line). Before staging, run `git diff` and take a screenshot. In two sentences: what do the lines starting with `-` and `+` mean? Then stage and commit with the message "Update README", and push to GitHub so the grader can see this commit and the previous one.

# %% [markdown]
# *Commands, answer, and screenshot (where asked) here.*

# %% [markdown]
# ### Task 11
#
# On GitHub, open an issue in your `reading-list` repository titled "Add five more books", with a one-line description of the idea. Issues let you track plans for a project without changing any files. Paste the issue's URL here.

# %% [markdown]
# *Commands, answer, and screenshot (where asked) here.*

# %% [markdown]
# ### Task 12
#
# In two or three sentences: what is the difference between cloning a repository and forking it? Give one situation where you need a fork.

# %% [markdown]
# *Commands, answer, and screenshot (where asked) here.*
