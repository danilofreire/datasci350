# %% [markdown]
# # DATASCI 350 - Data Science Computing
#
# ## Assignment 06 - Local Language Models
#
# ### Instructions
#
# This assignment evaluates your understanding of local language models, covered in lecture 12: tokens and embeddings, the model file, system prompts, temperature, the `Modelfile`, structured output, and where models fail.
#
# Every hands-on task uses Ollama and `llama3.2:1b`, the model from lecture 12. Before you start, check that `ollama ls` lists it. Nothing in this assignment needs an internet connection after that.
#
# Language models are not deterministic unless you make them so. If your model does something different from what the slides show, that is a valid result: report what yours did, and paste the actual output. Do not edit outputs.
#
# You must complete this assignment individually. You may use notes, books, and AI tools, but you must submit original work. I strongly recommend that you do not use AI tools to generate your solutions, as this will not help you learn the material. Acknowledge all resources used, including input from classmates and AI, in a short note at the end of your submission. If you are unsure about permissible resources or proper acknowledgement, please ask the instructor.
#
# ### Submission
#
# Please submit your solutions as either a single Jupyter notebook or a PDF file. For each task, paste the commands you ran, any `Modelfile` you wrote, the model's output, and your written answer where the task asks for one. Screenshots are welcome but not required if you paste the text. Submit your completed assignment to Canvas.

# %% [markdown]
# ### Task 01: meaning as geometry
#
# In your own words, explain why the vector arithmetic king − man + woman ≈ queen works. Your answer must use the terms "embedding" and "direction" and be no longer than four sentences.
#
# Then propose one analogy of your own in the same form (a − b + c ≈ d), different from the three on the slides, and state in one sentence what the direction a − b represents.

# %% [markdown]
# *Commands, output, and answer here.*

# %% [markdown]
# ### Task 02: read the model file
#
# Run `ollama show llama3.2:1b` and paste the output. Then, for each of these four fields, write one sentence saying what the number means: `parameters`, `context length`, `embedding length`, and `quantization`.
#
# For `context length`, convert the number to an approximate word count using the rule of thumb from the slides.

# %% [markdown]
# *Commands, output, and answer here.*

# %% [markdown]
# ### Task 03: a persona with PTCF
#
# Write a `Modelfile` for a persona of your choice (not Jeeves or Hobbes). The `SYSTEM` block must contain all four PTCF parts, in this order: Persona, Task, Context, Format. Mark each part with a comment line inside the block, for example `# Persona`. Set `FROM llama3.2:1b` and a temperature of your choice.
#
# Build it with `ollama create <name> -f <file>`, run it, and ask it one question. Paste the `Modelfile`, the build command, and the exchange.

# %% [markdown]
# *Commands, output, and answer here.*

# %% [markdown]
# ### Task 04: tone versus rules
#
# Add these three rules to the `SYSTEM` block of your Task 03 persona, keeping everything else the same:
#
# 1. Answer in three sentences at most.
# 2. Address the user by a fixed title of your choice (for example "my dear" or "captain") in every reply.
# 3. If asked to do something it cannot do, say so plainly instead of inventing an answer.
#
# Rebuild the model. Ask it exactly these three questions, in a fresh session (`/clear` before each one):
#
# - "Good morning. I need you to fix a bug in my Python script."
# - "Please email my professor to say I will miss class tomorrow."
# - "How many unread messages do I have in my inbox right now?"
#
# Paste the three answers. For each answer, state which of the three rules it followed and which it broke. Then, in one sentence: which was the model better at, keeping the tone or keeping the rules?

# %% [markdown]
# *Commands, output, and answer here.*

# %% [markdown]
# ### Task 05: two personas, one file
#
# Create a second persona from the same base model. Hint: copy your Task 03 `Modelfile` to a new file, change only the `SYSTEM` block, and build it with `ollama create` under a different name.
#
# Run `ollama ls` and paste the output. Then measure how much disk space the Ollama models folder really uses:
#
# - macOS or Linux: `du -sh ~/.ollama/models`
# - Windows (PowerShell): `(Get-ChildItem "$env:USERPROFILE\.ollama\models" -Recurse | Measure-Object -Property Length -Sum).Sum / 1GB`
#
# Paste the result. In two sentences: what size does `ollama ls` report for each persona, and why does the folder not add up to the sum of those sizes?

# %% [markdown]
# *Commands, output, and answer here.*

# %% [markdown]
# ### Task 06: the shape is constrained
#
# Run this command and paste the output:
#
# ```bash
# ollama run llama3.2:1b --format json "What is the capital of France?"
# ```
#
# Check the population and the coordinates against Wikipedia. Say which are wrong and give the correct values. Then, in one sentence: what does `--format json` guarantee, and what does it not guarantee?

# %% [markdown]
# *Commands, output, and answer here.*

# %% [markdown]
# ### Task 07: a headline classifier
#
# Save this as a file called `Classifier`:
#
# ```text
# FROM llama3.2:1b
# PARAMETER temperature 0
# SYSTEM """
# You classify news headlines. Reply with JSON only,
# using exactly these keys: "sentiment" (one of
# "bullish", "bearish", "neutral") and "confidence"
# (a number between 0 and 1). Do not add any other text.
# """
# ```
#
# Build it with `ollama create classifier -f Classifier`. Then classify each of these five headlines with `ollama run classifier --format json "<headline>"`, one command per headline:
#
# 1. "Central bank raises interest rates for the third time this year"
# 2. "Retailer reports record holiday sales"
# 3. "Airline cancels hundreds of flights after software failure"
# 4. "Tech giant announces share buyback programme"
# 5. "Oil prices unchanged as markets await supply report"
#
# Paste the five commands and the five JSON outputs. Then pipe the output for headline 2 into Python so that only the sentiment is printed, as on the "Structured output" slide, and paste that command and its output.

# %% [markdown]
# *Commands, output, and answer here.*

# %% [markdown]
# ### Task 08: a classifier that changes its mind
#
# Copy `Classifier` to a new file called `Classifier-hot`, change the temperature to 1, and build it as `classifier-hot`. Classify headlines 1 and 4 from Task 07 three times each (six commands in total; each `ollama run` command is a new session, so no `/clear` is needed). These two headlines were chosen because a reader could defend more than one label for each.
#
# Paste the six outputs. How many of the six labels differ from your Task 07 answer for the same headline? In one sentence: why does the slide say that a classifier that changes its mind between runs is not a classifier?

# %% [markdown]
# *Commands, output, and answer here.*

# %% [markdown]
# ### Task 09: what temperature 0 does
#
# A colleague says: "I set the temperature to 0, so the answers are correct now."
#
# In no more than three sentences, explain what temperature 0 does and what it does not do. Use two examples from this assignment or the slides: one where temperature 0 helped (the slogan experiment or your Task 07 classifier) and one where it would not have helped (the Paris JSON from Task 06).

# %% [markdown]
# *Commands, output, and answer here.*

# %% [markdown]
# ### Task 10: three kinds of instruction
#
# Lecture 12 used three ways to shape a model's output: a rule in the `SYSTEM` block, a `MESSAGE` example, and the `--format json` flag.
#
# Order the three from strongest guarantee to weakest. In one short paragraph, say what each one guarantees and what it leaves to chance, using evidence from Tasks 04, 06, and 07.

# %% [markdown]
# *Commands, output, and answer here.*

# %% [markdown]
# ### Task 11: hallucinated citations
#
# Run `ollama run llama3.2:1b` and ask exactly this:
#
# > "Give me three peer-reviewed journal articles on the effects of sleep deprivation on cognitive performance in adults. For each, give the authors, title, journal, year, and DOI."
#
# Paste the answer. Then check each DOI by opening `https://doi.org/<DOI>` in your browser. For each of the three, report one of: "DOI does not resolve", "DOI resolves to a different paper" (say which), or "DOI resolves to the paper as described".
#
# In two sentences: how many of the three were real, and why did nothing in the model's tone warn you?

# %% [markdown]
# *Commands, output, and answer here.*

# %% [markdown]
# ### Task 12: bias, and what changes it
#
# Run `ollama run llama3.2:1b`, set the temperature to 0 with `/set parameter temperature 0`, and ask exactly this:
#
# > "List ten famous scientists."
#
# Paste the list. Count how many are women, and how many were born outside Europe and North America. Then `/clear` and ask exactly this:
#
# > "List ten famous scientists. Include at least five women and scientists born on at least four different continents."
#
# Paste the second list and the same two counts. In two sentences: did naming the constraint change the list, and why does the model not produce a list like the second one unless asked?

# %% [markdown]
# *Commands, output, and answer here.*
